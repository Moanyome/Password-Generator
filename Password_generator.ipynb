# %% [markdown]
# <a href="https://colab.research.google.com/github/Moanyome/Password-Generator/blob/main/Password_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print('Your password')

chars = 'abcdefghijklmnopqrstuvwxyz123456789!@#$%^&*()?'

password = ''
for x in range(16):
    password += random.choice(chars)

print(password)
# Out:
# Your password
# f#@nhd$z&l@o*63x

# %% [markdown]
# password generator
